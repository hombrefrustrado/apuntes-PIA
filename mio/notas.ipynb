# %% [markdown]
# Desplazamiento interno de covariables $\to$ Esto son los cambios de distribución de probabilidad en las capas, que hace que al ajustar un modelo se vuelva más complicado ya que son interdependientes. Pero se arregla con batch normalization.
